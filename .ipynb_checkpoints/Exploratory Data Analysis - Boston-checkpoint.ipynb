# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import glob
import csv
import pandas as pd

# %%
# Read in all the dataset
data_file_paths = glob.glob("UberMovementData/Uber-Boston*")

# %%
datas = []
for fname in data_file_paths: # Read file name
    data= pd.read_csv(fname)
    # Find column names
    # list(data)
    frames = [datas, data]
    datas = pd.concat(frames)

    #datas.append(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-61c248d96c22> in <module>()
#       6     data = pd.DataFrame(data)
#       7     frames = [datas, data]
# ----> 8     datas = pd.concat(frames)
#       9
#      10     #datas.append(data)
#
# /Users/ivanzhou/General_Software/anaconda/lib/python3.5/site-packages/pandas/tools/merge.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#    1449                        keys=keys, levels=levels, names=names,
#    1450                        verify_integrity=verify_integrity,
# -> 1451                        copy=copy)
#    1452     return op.get_result()
#    1453
#
# /Users/ivanzhou/General_Software/anaconda/lib/python3.5/site-packages/pandas/tools/merge.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
# ...

# %%
datas
# Out:
# [[[[[[[[[[[],      Origin Movement ID                  Origin Display Name  \
#           0                   885  100 Summer Street, Downtown, Boston
#           1                   885  100 Summer Street, Downtown, Boston
#           2                   885  100 Summer Street, Downtown, Boston
#           3                   885  100 Summer Street, Downtown, Boston
#           4                   885  100 Summer Street, Downtown, Boston
#           5                   885  100 Summer Street, Downtown, Boston
#           6                   885  100 Summer Street, Downtown, Boston
#           7                   885  100 Summer Street, Downtown, Boston
#           8                   885  100 Summer Street, Downtown, Boston
#           9                   885  100 Summer Street, Downtown, Boston
#           10                  885  100 Summer Street, Downtown, Boston
#           11                  885  100 Summer Street, Downtown, Boston
# ...

# %%
data.pivot(index=list(data)[4], columns=list(data)[6], values=list(data)[7])
# Out:
# Date Range                                          02/22/2016 - 02/28/2016, Mondays, 07:00AM-09:00AM
# Destination Display Name
# 0 Academy Road, Roxbury, Boston                                                                   835
# 0 Atkins Street, Brighton, Boston                                                                 740
# 0 Bates Road, Winchester                                                                         1031
# 0 Binney Street, Arefth, Cambridge                                                               1073
# 0 Blossom Street, West End, Boston                                                                550
# 0 Boatswains Way, Chelsea                                                                         567
# 0 Boston Street, Prospect Hill, Somerville                                                       1136
# 0 Braintree Street, Allston, Boston                                                               644
# ...
