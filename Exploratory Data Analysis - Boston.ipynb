# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import glob
import csv
import pandas as pd

# %% [markdown]
# ## Import Data sets
# We import all the datasets and store in a list called `all_data`. Then we also create a dataframe called `data_merge` to merge and store all the datasets

# %%
# Read in all the dataset
data_file_paths = glob.glob("UberMovementData/Uber-Boston*")

all_data = []
for fname in data_file_paths: # Read file name
    data= pd.read_csv(fname)
    all_data.append(data)
    # Find column names
    # list(data)

# %%
# Merge all the datasets and store in one dataframe called data_merge
data_merge = all_data[0]

for i in range(1,len(all_data)):
    next_data = all_data[i]
    frames = [data_merge,next_data]
    data_merge = pd.concat(frames)

# %%
# Find dataframe dimensions
data_merge.shape
# Out:
# (1181, 10)

# %%
# Example Row
#list(data_merge)
data_merge[:1]
# Out:
#    Origin Movement ID                  Origin Display Name  \
# 0                 885  100 Summer Street, Downtown, Boston
#
#                                      Origin Geometry  Destination Movement ID  \
# 0  [[-71.064235,42.353394],[-71.063308,42.355209]...                        3
#
#                            Destination Display Name  \
# 0  0 Flaherty Way, D Street / West Broadway, Boston
#
#                                 Destination Geometry  \
# 0  [[-71.05624,42.338869],[-71.053928,42.340791],...
#
#                                           Date Range  \
# 0  02/22/2016 - 02/28/2016, Mondays, 07:00AM-09:00AM
#
#    Mean Travel Time (Seconds)  Range - Lower Bound Travel Time (Seconds)  \
# 0                         508                                        291
#
#    Range - Upper Bound Travel Time (Seconds)
# 0                                        886

# %% [markdown]
# ## Exploratory Data Analysis

# %%
col_names = list(data_merge)
data_merge.pivot(col_names[4], columns=col_names[6], values=col_names[7])
# Out:
# Date Range                                          02/22/2016 - 02/28/2016, Fridays, 07:00AM-09:00AM  \
# Destination Display Name
# 0 6th Street, Arefth, Cambridge                                                                   NaN
# 0 Academy Road, Roxbury, Boston                                                                 988.0
# 0 Atkins Street, Brighton, Boston                                                               529.0
# 0 Badger Road, Framingham                                                                         NaN
# 0 Bates Road, Winchester                                                                          NaN
# 0 Bent Avenue, Cochituate, Wayland                                                                NaN
# 0 Binney Street, Arefth, Cambridge                                                              918.0
# 0 Blossom Street, West End, Boston                                                              491.0
# ...
